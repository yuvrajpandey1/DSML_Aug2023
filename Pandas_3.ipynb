# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## IMDB Case-Study

# %%
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#    Unnamed: 0     id     budget  popularity     revenue  \
# 0           0  43597  237000000         150  2787965087
# 1           1  43598  300000000         139   961000000
# 2           2  43599  245000000         107   880674609
# 3           3  43600  250000000         112  1084939099
# 4           5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 4         4767  2007   May   Tuesday

# %%
# remove Unnamed col its a extra index col
movies = pd.read_csv('movies.csv',index_col=0)
movies.head()
# Out:
#       id     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 5  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  \
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 5                              Spider-Man 3           5.9        3576
#
#    director_id  year month       day
# 0         4762  2009   Dec  Thursday
# 1         4763  2007   May  Saturday
# 2         4764  2015   Oct    Monday
# 3         4765  2012   Jul    Monday
# 5         4767  2007   May   Tuesday

# %%
directors = pd.read_csv('directors.csv',index_col=0)
directors.head()
# Out:
#        director_name    id gender
# 0      James Cameron  4762   Male
# 1     Gore Verbinski  4763   Male
# 2         Sam Mendes  4764   Male
# 3  Christopher Nolan  4765   Male
# 4     Andrew Stanton  4766   Male

# %%
data=movies.merge(directors, how='left',left_on='director_id',right_on='id')
data.drop(['director_id','id_y'],axis=1,inplace=True)

# %%
data.head()
# Out:
#     id_x     budget  popularity     revenue  \
# 0  43597  237000000         150  2787965087
# 1  43598  300000000         139   961000000
# 2  43599  245000000         107   880674609
# 3  43600  250000000         112  1084939099
# 4  43602  258000000         115   890871626
#
#                                       title  vote_average  vote_count  year  \
# 0                                    Avatar           7.2       11800  2009
# 1  Pirates of the Caribbean: At World's End           6.9        4500  2007
# 2                                   Spectre           6.3        4466  2015
# 3                     The Dark Knight Rises           7.6        9106  2012
# 4                              Spider-Man 3           5.9        3576  2007
#
#   month       day      director_name gender
# 0   Dec  Thursday      James Cameron   Male
# 1   May  Saturday     Gore Verbinski   Male
# 2   Oct    Monday         Sam Mendes   Male
# 3   Jul    Monday  Christopher Nolan   Male
# 4   May   Tuesday          Sam Raimi   Male

# %%
# Encoding male --> o
# female --> 1

# %%
def encode(text):
    if text =="Male":
        return 0
    else:
        return 1

# %%
data.iloc[0]['gender']
# Out:
# 'Male'

# %%
# passing function
encode(data.iloc[0]['gender'])
# Out:
# 0

# %%
# apply function on whole gender column
data['gender'].apply(encode)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1460    0
# 1461    0
# 1462    0
# 1463    0
# 1464    1
# Name: gender, Length: 1465, dtype: int64

# %%
data['gender_mapping'] = data['gender'].apply(encode)

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 1460                            The Last Waltz           7.9          64
# 1461                                    Clerks           7.4         755
# 1462                                   Rampage           6.0         131
# 1463                                   Slacker           6.4          77
# 1464                               El Mariachi           6.6         238
#
#       year month       day      director_name gender  gender_mapping
# 0     2009   Dec  Thursday      James Cameron   Male               0
# 1     2007   May  Saturday     Gore Verbinski   Male               0
# 2     2015   Oct    Monday         Sam Mendes   Male               0
# 3     2012   Jul    Monday  Christopher Nolan   Male               0
# 4     2007   May   Tuesday          Sam Raimi   Male               0
# ...    ...   ...       ...                ...    ...             ...
# 1460  1978   May    Monday    Martin Scorsese   Male               0
# 1461  1994   Sep   Tuesday        Kevin Smith   Male               0
# 1462  2009   Aug    Friday           Uwe Boll   Male               0
# 1463  1990   Jul    Friday  Richard Linklater   Male               0
# 1464  1992   Sep    Friday   Robert Rodriguez    NaN               1
#
# [1465 rows x 13 columns]

# %% [markdown]
# #### How to find sum of revenue and budget per movie
# * Multiple col

# %%
data[['revenue','budget']].apply(np.sum)
# Out:
# revenue    209866997305
# budget      70353617179
# dtype: int64

# %%
# Row wise
data[['revenue','budget']].apply(np.sum,axis=1)
# Out:
# 0       3024965087
# 1       1261000000
# 2       1125674609
# 3       1334939099
# 4       1148871626
#            ...
# 1460        321952
# 1461       3178130
# 1462             0
# 1463             0
# 1464       2260920
# Length: 1465, dtype: int64

# %% [markdown]
# ### How to find Profit per movie(revenue-budget)

# %%
def proof(x):
    return x['revenue'] - x['budget']
    
    
data['profit'] = data[['revenue','budget']].apply(proof,axis=1)
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 1460                            The Last Waltz           7.9          64
# 1461                                    Clerks           7.4         755
# 1462                                   Rampage           6.0         131
# 1463                                   Slacker           6.4          77
# 1464                               El Mariachi           6.6         238
#
#       year month       day      director_name gender  gender_mapping  \
# 0     2009   Dec  Thursday      James Cameron   Male               0
# 1     2007   May  Saturday     Gore Verbinski   Male               0
# 2     2015   Oct    Monday         Sam Mendes   Male               0
# 3     2012   Jul    Monday  Christopher Nolan   Male               0
# 4     2007   May   Tuesday          Sam Raimi   Male               0
# ...    ...   ...       ...                ...    ...             ...
# 1460  1978   May    Monday    Martin Scorsese   Male               0
# 1461  1994   Sep   Tuesday        Kevin Smith   Male               0
# 1462  2009   Aug    Friday           Uwe Boll   Male               0
# 1463  1990   Jul    Friday  Richard Linklater   Male               0
# 1464  1992   Sep    Friday   Robert Rodriguez    NaN               1
#
#           profit
# 0     2550965087
# 1      661000000
# 2      635674609
# 3      834939099
# 4      632871626
# ...          ...
# 1460      321952
# 1461     3124130
# 1462           0
# 1463           0
# 1464     1820920
#
# [1465 rows x 14 columns]

# %% [markdown]
# #### apply function
# * apply a function on a dataframe
# * create a function/inbuilt function np sum
# * Column on a dataframe and then you need to pass to function

# %% [markdown]
# ### Group By

# %%
# How can we know the number of movies released by a particular director, say, Christopher Nolan?

# %%
data['director_name'] =='Christopher Nolan'
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: director_name, Length: 1465, dtype: bool

# %%
data.loc[data['director_name'] =='Christopher Nolan']
# Out:
#        id_x     budget  popularity     revenue                  title  \
# 3     43600  250000000         112  1084939099  The Dark Knight Rises
# 45    43662  185000000         187  1004558444        The Dark Knight
# 58    43692  165000000         724   675120017           Interstellar
# 59    43693  160000000         167   825532764              Inception
# 74    43716  150000000         115   374218673          Batman Begins
# 565   44630   46000000          41   113714830               Insomnia
# 641   44793   40000000          74   109676311           The Prestige
# 1341  47170    9000000          60    39723096                Memento
#
#       vote_average  vote_count  year month        day      director_name  \
# 3              7.6        9106  2012   Jul     Monday  Christopher Nolan
# 45             8.2       12002  2008   Jul  Wednesday  Christopher Nolan
# 58             8.1       10867  2014   Nov  Wednesday  Christopher Nolan
# 59             8.1       13752  2010   Jul  Wednesday  Christopher Nolan
# 74             7.5        7359  2005   Jun     Friday  Christopher Nolan
# 565            6.8        1148  2002   May     Friday  Christopher Nolan
# 641            8.0        4391  2006   Oct   Thursday  Christopher Nolan
# 1341           8.1        4028  2000   Oct  Wednesday  Christopher Nolan
#
#      gender  gender_mapping     profit
# 3      Male               0  834939099
# 45     Male               0  819558444
# 58     Male               0  510120017
# 59     Male               0  665532764
# 74     Male               0  224218673
# 565    Male               0   67714830
# 641    Male               0   69676311
# 1341   Male               0   30723096

# %%
data.loc[data['director_name'] =='Christopher Nolan','title'].count()
# Out:
# 8

# %%
### Movie of each director

# %%
data['director_name'].value_counts()
# Out:
# Steven Spielberg      26
# Martin Scorsese       19
# Clint Eastwood        19
# Woody Allen           18
# Ridley Scott          16
#                       ..
# Tim Hill               5
# Jonathan Liebesman     5
# Roman Polanski         5
# Larry Charles          5
# Nicole Holofcener      5
# Name: director_name, Length: 199, dtype: int64

# %%
data['director_name'].nunique()
# Out:
# 199

# %%
# groupby object
data.groupby('director_name')

# %%
# Total no of group
data.groupby('director_name').ngroups
# Out:
# 199

# %%
data.groupby('director_name').groups
# Out:
# {'Adam McKay': [176, 323, 366, 505, 839, 916], 'Adam Shankman': [265, 300, 350, 404, 458, 843, 999, 1231], 'Alejandro González Iñárritu': [106, 749, 1015, 1034, 1077, 1405], 'Alex Proyas': [95, 159, 514, 671, 873], 'Alexander Payne': [793, 1006, 1101, 1211, 1281], 'Andrew Adamson': [11, 43, 328, 501, 947], 'Andrew Niccol': [533, 603, 701, 722, 1439], 'Andrzej Bartkowiak': [349, 549, 754, 911, 924], 'Andy Fickman': [517, 681, 909, 926, 973, 1023], 'Andy Tennant': [314, 320, 464, 593, 676, 885], 'Ang Lee': [99, 134, 748, 840, 1089, 1110, 1132, 1184], 'Anne Fletcher': [610, 650, 736, 789, 1206], 'Antoine Fuqua': [310, 338, 424, 467, 576, 808, 818, 1105], 'Atom Egoyan': [946, 1128, 1164, 1194, 1347, 1416], 'Barry Levinson': [313, 319, 471, 594, 878, 898, 1013, 1037, 1082, 1143, 1185, 1345, 1378], 'Barry Sonnenfeld': [13, 48, 90, 205, 591, 778, 783], 'Ben Stiller': [209, 212, 547, 562, 850], 'Bill Condon': [102, 307, 902, 1233, 1381], 'Bobby Farrelly': [352, 356, 481, 498, 624, 630, 654, 806, 928, 972, 1111], 'Brad Anderson': [1163, 1197, 1350, 1419, 1430], 'Brett Ratner': [24, 39, 188, 207, 238, 292, 405, 456, 920], 'Brian De Palma': [228, 255, 318, 439, 747, 905, 919, 1088, 1232, 1261, 1317, 1354], 'Brian Helgeland': [512, 607, 623, 742, 933], 'Brian Levant': [418, 449, 568, 761, 860, 1003], 'Brian Robbins': [416, 441, 669, 962, 988, 1115], 'Bryan Singer': [6, 32, 33, 44, 122, 216, 297, 1326], 'Cameron Crowe': [335, 434, 488, 503, 513, 698], 'Catherine Hardwicke': [602, 695, 724, 937, 1406, 1412], 'Chris Columbus': [117, 167, 204, 218, 229, 509, 656, 897, 996, 1086, 1129], 'Chris Weitz': [17, 500, 794, 869, 1202, 1267], 'Christopher Nolan': [3, 45, 58, 59, 74, 565, 641, 1341], 'Chuck Russell': [177, 410, 657, 1069, 1097, 1339], 'Clint Eastwood': [369, 426, 447, 482, 490, 520, 530, 535, 645, 727, 731, 786, 787, 899, 974, 986, 1167, 1190, 1313], 'Curtis Hanson': [494, 579, 606, 711, 733, 1057, 1310], 'Danny Boyle': [527, 668, 1083, 1085, 1126, 1168, 1287, 1385], 'Darren Aronofsky': [113, 751, 1187, 1328, 1363, 1458], 'Darren Lynn Bousman': [1241, 1243, 1283, 1338, 1440], 'David Ayer': [50, 273, 741, 1024, 1146, 1407], 'David Cronenberg': [541, 767, 994, 1055, 1254, 1268, 1334], 'David Fincher': [62, 213, 253, 383, 398, 478, 522, 555, 618, 785], 'David Gordon Green': [543, 862, 884, 927, 1376, 1418, 1432, 1459], 'David Koepp': [443, 644, 735, 1041, 1209], 'David Lynch': [583, 1161, 1264, 1340, 1456], 'David O. Russell': [422, 556, 609, 896, 982, 989, 1229, 1304], 'David R. Ellis': [582, 634, 756, 888, 934], 'David Zucker': [569, 619, 965, 1052, 1175], 'Dennis Dugan': [217, 260, 267, 293, 303, 718, 780, 977, 1247], 'Donald Petrie': [427, 507, 570, 649, 858, 894, 1106, 1331], 'Doug Liman': [52, 148, 251, 399, 544, 1318, 1451], 'Edward Zwick': [92, 182, 346, 566, 791, 819, 825], 'F. Gary Gray': [308, 402, 491, 523, 697, 833, 1272, 1380], 'Francis Ford Coppola': [487, 559, 622, 646, 772, 1076, 1155, 1253, 1312], 'Francis Lawrence': [63, 72, 109, 120, 679], 'Frank Coraci': [157, 249, 275, 451, 577, 599, 963], 'Frank Oz': [193, 355, 473, 580, 712, 813, 987], 'Garry Marshall': [329, 496, 528, 571, 784, 893, 1029, 1169], 'Gary Fleder': [518, 667, 689, 867, 981, 1165], 'Gary Winick': [258, 797, 798, 804, 1454], 'Gavin O'Connor': [820, 841, 939, 953, 1444], 'George A. Romero': [250, 1066, 1096, 1278, 1367, 1396], 'George Clooney': [343, 450, 831, 966, 1302], 'George Miller': [78, 103, 233, 287, 1250, 1403, 1450], 'Gore Verbinski': [1, 8, 9, 107, 119, 633, 1040], 'Guillermo del Toro': [35, 252, 419, 486, 1118], 'Gus Van Sant': [595, 1018, 1027, 1159, 1240, 1311, 1398], 'Guy Ritchie': [124, 215, 312, 1093, 1225, 1269, 1420], 'Harold Ramis': [425, 431, 558, 586, 788, 1137, 1166, 1325], 'Ivan Reitman': [274, 643, 816, 883, 910, 935, 1134, 1242], 'James Cameron': [0, 19, 170, 173, 344, 1100, 1320], 'James Ivory': [1125, 1152, 1180, 1291, 1293, 1390, 1397], 'James Mangold': [140, 141, 557, 560, 829, 845, 958, 1145], 'James Wan': [30, 617, 1002, 104 ...

# %%
## Specific person group
data.groupby('director_name').get_group('Alexander Payne')
# all movie of Alexander Payne
# Out:
#        id_x    budget  popularity    revenue            title  vote_average  \
# 793   45163  30000000          19  105834556    About Schmidt           6.7
# 1006  45699  20000000          40  177243185  The Descendants           6.7
# 1101  46004  16000000          23  109502303         Sideways           6.9
# 1211  46446  12000000          29   17654912         Nebraska           7.4
# 1281  46813         0          13          0         Election           6.7
#
#       vote_count  year month       day    director_name gender  \
# 793          362  2002   Dec    Friday  Alexander Payne    NaN
# 1006         934  2011   Sep    Friday  Alexander Payne    NaN
# 1101         478  2004   Oct    Friday  Alexander Payne    NaN
# 1211         636  2013   Sep  Saturday  Alexander Payne    NaN
# 1281         270  1999   Apr    Friday  Alexander Payne    NaN
#
#       gender_mapping     profit
# 793                1   75834556
# 1006               1  157243185
# 1101               1   93502303
# 1211               1    5654912
# 1281               1          0

# %%
data.groupby('director_name').get_group('Christopher Nolan')
# Out:
#        id_x     budget  popularity     revenue                  title  \
# 3     43600  250000000         112  1084939099  The Dark Knight Rises
# 45    43662  185000000         187  1004558444        The Dark Knight
# 58    43692  165000000         724   675120017           Interstellar
# 59    43693  160000000         167   825532764              Inception
# 74    43716  150000000         115   374218673          Batman Begins
# 565   44630   46000000          41   113714830               Insomnia
# 641   44793   40000000          74   109676311           The Prestige
# 1341  47170    9000000          60    39723096                Memento
#
#       vote_average  vote_count  year month        day      director_name  \
# 3              7.6        9106  2012   Jul     Monday  Christopher Nolan
# 45             8.2       12002  2008   Jul  Wednesday  Christopher Nolan
# 58             8.1       10867  2014   Nov  Wednesday  Christopher Nolan
# 59             8.1       13752  2010   Jul  Wednesday  Christopher Nolan
# 74             7.5        7359  2005   Jun     Friday  Christopher Nolan
# 565            6.8        1148  2002   May     Friday  Christopher Nolan
# 641            8.0        4391  2006   Oct   Thursday  Christopher Nolan
# 1341           8.1        4028  2000   Oct  Wednesday  Christopher Nolan
#
#      gender  gender_mapping     profit
# 3      Male               0  834939099
# 45     Male               0  819558444
# 58     Male               0  510120017
# 59     Male               0  665532764
# 74     Male               0  224218673
# 565    Male               0   67714830
# 641    Male               0   69676311
# 1341   Male               0   30723096

# %%
data.groupby('director_name').get_group('Christopher Nolan')['title']
# Out:
# 3       The Dark Knight Rises
# 45            The Dark Knight
# 58               Interstellar
# 59                  Inception
# 74              Batman Begins
# 565                  Insomnia
# 641              The Prestige
# 1341                  Memento
# Name: title, dtype: object

# %%
data.groupby('director_name').get_group('Christopher Nolan')['title'].count()
# Out:
# 8

# %%
## How can we find multiple aggregation of any feature?

# %%
data['year']
# Out:
# 0       2009
# 1       2007
# 2       2015
# 3       2012
# 4       2007
#         ...
# 1460    1978
# 1461    1994
# 1462    2009
# 1463    1990
# 1464    1992
# Name: year, Length: 1465, dtype: int64

# %%
data.groupby('director_name')['year'].min()
# Out:
# director_name
# Adam McKay                     2004
# Adam Shankman                  2001
# Alejandro González Iñárritu    2000
# Alex Proyas                    1994
# Alexander Payne                1999
#                                ...
# Wes Craven                     1984
# Wolfgang Petersen              1981
# Woody Allen                    1977
# Zack Snyder                    2004
# Zhang Yimou                    2002
# Name: year, Length: 199, dtype: int64

# %%
data.groupby('director_name')['year'].max()
# Out:
# director_name
# Adam McKay                     2015
# Adam Shankman                  2012
# Alejandro González Iñárritu    2015
# Alex Proyas                    2016
# Alexander Payne                2013
#                                ...
# Wes Craven                     2011
# Wolfgang Petersen              2006
# Woody Allen                    2013
# Zack Snyder                    2016
# Zhang Yimou                    2014
# Name: year, Length: 199, dtype: int64

# %%
# First and last movie
data.groupby('director_name')['year'].aggregate(['min','max'])
# Out:
#                               min   max
# director_name
# Adam McKay                   2004  2015
# Adam Shankman                2001  2012
# Alejandro González Iñárritu  2000  2015
# Alex Proyas                  1994  2016
# Alexander Payne              1999  2013
# ...                           ...   ...
# Wes Craven                   1984  2011
# Wolfgang Petersen            1981  2006
# Woody Allen                  1977  2013
# Zack Snyder                  2004  2016
# Zhang Yimou                  2002  2014
#
# [199 rows x 2 columns]

# %%
## We can get highest budget movie for every director

# %%
data.groupby('director_name')['budget'].aggregate(['min','max'])
# Out:
#                                   min        max
# director_name
# Adam McKay                   26000000  100000000
# Adam Shankman                11000000   80000000
# Alejandro González Iñárritu         0  135000000
# Alex Proyas                  15000000  140000000
# Alexander Payne                     0   30000000
# ...                               ...        ...
# Wes Craven                    1800000   40000000
# Wolfgang Petersen            14000000  175000000
# Woody Allen                         0   30000000
# Zack Snyder                  28000000  250000000
# Zhang Yimou                         0   94000000
#
# [199 rows x 2 columns]

# %%
data.groupby('director_name')['budget'].max()
# Out:
# director_name
# Adam McKay                     100000000
# Adam Shankman                   80000000
# Alejandro González Iñárritu    135000000
# Alex Proyas                    140000000
# Alexander Payne                 30000000
#                                  ...
# Wes Craven                      40000000
# Wolfgang Petersen              175000000
# Woody Allen                     30000000
# Zack Snyder                    250000000
# Zhang Yimou                     94000000
# Name: budget, Length: 199, dtype: int64

# %%
### How can we filter_out the director name with max budget > 100M  ?

# %%
data_dir_budget = data.groupby('director_name')['budget'].max().reset_index()
data_dir_budget.head()
# Out:
#                  director_name     budget
# 0                   Adam McKay  100000000
# 1                Adam Shankman   80000000
# 2  Alejandro González Iñárritu  135000000
# 3                  Alex Proyas  140000000
# 4              Alexander Payne   30000000

# %%
names = data_dir_budget.loc[data_dir_budget['budget'] >= 100000000, 'director_name']

# %%
names
# Out:
# 0                       Adam McKay
# 2      Alejandro González Iñárritu
# 3                      Alex Proyas
# 5                   Andrew Adamson
# 10                         Ang Lee
#                   ...
# 187                    Tom Shadyac
# 188                     Tom Tykwer
# 189                     Tony Scott
# 195              Wolfgang Petersen
# 197                    Zack Snyder
# Name: director_name, Length: 85, dtype: object

# %%
data['director_name'].isin(names)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1460     True
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: director_name, Length: 1465, dtype: bool

# %%
data.loc[data['director_name'].isin(names)]
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1450  48267     400000          33   100000000
# 1451  48268     200000          13     4505922
# 1452  48274          0           5     2611555
# 1458  48335      60000          27     3221152
# 1460  48363          0           3      321952
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 1450                                   Mad Max           6.6        1213
# 1451                                  Swingers           6.8         253
# 1452                                     Three           6.3          31
# 1458                                        Pi           7.1         586
# 1460                            The Last Waltz           7.9          64
#
#       year month       day      director_name gender  gender_mapping  \
# 0     2009   Dec  Thursday      James Cameron   Male               0
# 1     2007   May  Saturday     Gore Verbinski   Male               0
# 2     2015   Oct    Monday         Sam Mendes   Male               0
# 3     2012   Jul    Monday  Christopher Nolan   Male               0
# 4     2007   May   Tuesday          Sam Raimi   Male               0
# ...    ...   ...       ...                ...    ...             ...
# 1450  1979   Apr  Thursday      George Miller   Male               0
# 1451  1996   Oct    Friday         Doug Liman   Male               0
# 1452  2010   Dec  Thursday         Tom Tykwer   Male               0
# 1458  1998   Jul    Friday   Darren Aronofsky   Male               0
# 1460  1978   May    Monday    Martin Scorsese   Male               0
#
#           profit
# 0     2550965087
# 1      661000000
# 2      635674609
# 3      834939099
# 4      632871626
# ...          ...
# 1450    99600000
# 1451     4305922
# 1452     2611555
# 1458     3161152
# 1460      321952
#
# [679 rows x 14 columns]

# %% [markdown]
# ### Lambda Function

# %%
def add(a):
    a = a+10
    print(a)

# %%
add(2)
# Out:
# 12

# %%
#lambda input:output
x = lambda a:a+10

# %%
x(2)
# Out:
# 12

# %%
yuvraj = lambda x,y : x*y

# %%
yuvraj(3,4)
# Out:
# 12

# %%
# Create a lambda function that takes three values and add them

# %%
add =  lambda a,b,c: a+b+c

# %%
add(10,20,30)
# Out:
# 60

# %%
data.groupby('director_name')['vote_average'].max()
# Out:
# director_name
# Adam McKay                     7.3
# Adam Shankman                  7.5
# Alejandro González Iñárritu    7.6
# Alex Proyas                    7.3
# Alexander Payne                7.4
#                               ...
# Wes Craven                     7.2
# Wolfgang Petersen              7.9
# Woody Allen                    7.8
# Zack Snyder                    7.0
# Zhang Yimou                    7.2
# Name: vote_average, Length: 199, dtype: float64

# %%
data.groupby('director_name')['vote_average'].max().sort_values()
# Out:
# director_name
# Jason Friedberg      4.2
# John Whitesell       5.4
# Brian Levant         5.5
# Raja Gosnell         5.6
# Tim Hill             5.8
#                     ...
# Christopher Nolan    8.2
# Robert Zemeckis      8.2
# Quentin Tarantino    8.3
# Steven Spielberg     8.3
# David Fincher        8.3
# Name: vote_average, Length: 199, dtype: float64

# %%
data.groupby('director_name')['vote_average'].max().sort_values(ascending=False)
# Out:
# director_name
# David Fincher        8.3
# Steven Spielberg     8.3
# Quentin Tarantino    8.3
# Robert Zemeckis      8.2
# Christopher Nolan    8.2
#                     ...
# Tim Hill             5.8
# Raja Gosnell         5.6
# Brian Levant         5.5
# John Whitesell       5.4
# Jason Friedberg      4.2
# Name: vote_average, Length: 199, dtype: float64

# %%
data.groupby('director_name').filter( lambda x:x['vote_average'].max()>=8.3)
# Out:
#        id_x     budget  popularity    revenue  \
# 37    43650  185000000          75  786636033
# 62    43697  150000000          60  333932083
# 105   43772  140000000          44  183345589
# 110   43782  132000000          48  591739379
# 114   43787  130000000          89  371940071
# 166   43872  102000000          65  358372926
# 178   43884  100000000          82  425368238
# 213   43951   90000000          47  232617430
# 219   43960  100000000          34  235926552
# 253   44018   65000000          51   84785914
# 296   44105   73000000           2  229074524
# 304   44118   60000000          57  219417255
# 309   44125   70000000          29  130358911
# 332   44168   70000000          72  319131050
# 333   44169   70000000          33  300854823
# 342   44182   66000000          29  177584879
# 360   44225   70000000          76  481840909
# 363   44230   65000000          36  275293450
# 383   44259   63000000         146  100853753
# 390   44272   63000000          40  920100000
# 394   44281   44000000          68  155760117
# 398   44290   61000000         143  369330363
# 472   44425   30000000          79  180949000
# 474   44427   30000000          50  152159461
# 478   44435   50000000          45  159773545
# 495   44480   52000000          73  352114312
# 522   44543   50000000          62  109423648
# 552   44603   48000000          80  474171806
# 555   44607   48000000          53  196397415
# 618   44758   40000000          69  224920315
# 635   44784   40000000          48  165478348
# 647   44808   36000000           3   74000000
# 766   45107   35000000          10   31755742
# 785   45150   33000000          79  327311859
# 834   45294   28000000          66  333000000
# 901   45415   22000000         104  321365567
# 995   45682   18000000          68  389925971
# 997   45684   20000000          52  303788635
# 1135  46117   15000000          17  146292009
# 1207  46419   12000000          40   39673162
# 1239  46564   10500000          56  792910554
# 1252  46603   10000000          12   29450919
# 1284  46829    8000000         121  213928762
# 1426  47897    1200000          66   14661007
#
#                                                   title  vote_average  \
# 37    Indiana Jones and the Kingdom of the Crystal S...           5.7
# 62                  The Curious Case of Benjamin Button           7.3
# 105                                             The BFG           6.0
# 110                                   War of the Worlds           6.2
# 114                            The Adventures of Tintin           6.7
# 166                                     Minority Report           7.1
# 178                                    Django Unchained           7.8
# 213                     The Girl with the Dragon Tattoo           7.2
# 219                        A.I. Artificial Intelligence           6.8
# 253                                              Zodiac           7.3
# 296                       The Lost World: Jurassic Park           6.2
# 304                                        The Terminal           7.0
# 309                                              Munich           6.9
# 332                                Inglourious Basterds           7.9
# 333                                                Hook           6.6
# 342                                           War Horse           7.0
# 360                                 Saving Private Ryan           7.9
# 363                                             Lincoln           6.7
# 383                                          Fight Club           8.3
# 390                                       Jurassic Park           7.6
# 394                                   The Hateful Eight           7.6
# 398                                           Gone Girl           7.9
# 472                                   Kill Bill: Vol. 1           7.7
# 474                                   Kill Bill: Vol. 2           7.6
# 478                                              Alien³           6.2
# 495                                 Catch Me If You Can           7.7
# 522                                            The Game           7.5
# 552                  Indiana Jones and the Last Crusade           7.6
# 555                                          Panic Room           6.5
# 618                                  The Social Network           7.1
# 635                                     Bridge of Spies           7.2
# 647                                             Amistad           6.8
# 766                                                1941           5.6
# 785                                               Se7en           8.1
# 834                Indiana Jones and the Temple of Doom           7.1
# 901                                    Schindler's List           8.3
# 995                             Raiders of the Lost Ark           7.7
# 997                  Close Encounters of the Third Kind           7.2
# 1135                                   The Color Purple           7.7
# 1207                                       Jackie Brown           7.3
# 1239                         E.T. the Extra-Terrestrial           7.3
# 1252                           Twilight Zone: The Movie           6.2
# 1284                                       Pulp Fiction           8.3
# 1426                                     Reservoir Dogs           8.0
#
#       vote_count  year month        day      director_name gender  \
# 37          2495  2008   May  Wednesday   Steven Spielberg   Male
# 62          3292  2008   Nov     Monday      David Fincher   Male
# 105         1000  2016   Jun  Wednesday   Steven Spielberg   Male
# 110         2322  2005   Jun    Tuesday   Steven Spielberg   Male
# 114         2061  2011   Oct    Tuesday   Steven Spielberg   Male
# 166         2608  2002   Jun   Thursday   Steven Spielberg   Male
# 178        10099  2012   Dec    Tuesday  Quentin Tarantino   Male
# 213         2434  2011   Dec  Wednesday      David Fincher   Male
# 219         1974  2001   Jun     Friday   Steven Spielberg   Male
# 253         2023  2007   Mar     Friday      David Fincher   Male
# 296         2487  1997   May     Friday   Steven Spielberg   Male
# 304         1910  2004   Jun   Thursday   Steven Spielberg   Male
# 309          696  2005   Dec   Thursday   Steven Spielberg   Male
# 332         6430  2009   Aug    Tuesday  Quentin Tarantino   Male
# 333         1532  1991   Dec  Wednesday   Steven Spielberg   Male
# 342          992  2011   Dec     Sunday   Steven Spielberg   Male
# 360         5048  1998   Jul     Friday   Steven Spielberg   Male
# 363         1429  2012   Nov     Friday   Steven Spielberg   Male
# 383         9413  1999   Oct     Friday      David Fincher   Male
# 390         4856  1993   Jun     Friday   Steven Spielberg   Male
# 394         4274  2015   Dec     Friday  Quentin Tarantino   Male
# 398         5862  2014   Oct  Wednesday      David Fincher   Male
# 472         4949  2003   Oct     Friday  Quentin Tarantino   Male
# 474         3948  2004   Apr     Friday  Quentin Tarantino   Male
# 478         1633  1992   May     Friday      David Fincher   Male
# 495         3795  2002   Dec  Wednesday   Steven Spielberg   Male
# 522         1506  1997   Sep     Friday      David Fincher   Male
# 552         3152  1989   May  Wednesday   Steven Spielberg   Male
# 555         1267  2002   Mar     Friday      David Fincher   Male
# 618         3391  2010   Sep   Thursday      David Fincher   Male
# 635         2583  2015   Oct   Thursday   Steven Spielberg   Male
# 647          316  1997   Dec  Wednesday   Steven Spielberg   Male
# 766          143  1979   Dec   Thursday   Steven Spielberg   Male
# 785         5765  1995   Sep     Friday      David Fincher   Male
# 834         2781  1984   May  Wednesday   Steven Spielberg   Male
# 901         4329  1993   Nov     Monday   Steven Spielberg   Male
# 995         3854  1981   Jun     Friday   Steven Spielberg   Male
# 997         1098  1977   Nov  Wednesday   Steven Spielberg   Male
# 1135         338  1985   Dec  Wednesday   Steven Spielberg   Male
# 1207        1514  1997   Dec  Wednesday  Quentin Tarantino   Male
# 1239        3269  1982   Apr   Saturday   Steven Spielberg   Male
# 1252         161  1983   Jun     Friday   Steven Spielberg   Male
# 1284        8428  1994   Oct   Saturday  Quentin Tarantino   Male
# 1426        3697  1992   Sep  Wednesday  Quentin Tarantino   Male
#
#       gender_mapping     profit
# 37                 0  601636033
# 62                 0  183932083
# 105                0   43345589
# 110                0  459739379
# 114                0  241940071
# 166                0  256372926
# 178                0  325368238
# 213                0  142617430
# 219                0  135926552
# 253                0   19785914
# 296                0  156074524
# 304                0  159417255
# 309                0   60358911
# 332                0  249131050
# 333                0  230854823
# 342                0  111584879
# 360                0  411840909
# 363                0  210293450
# 383                0   37853753
# 390                0  857100000
# 394                0  111760117
# 398                0  308330363
# 472                0  150949000
# 474                0  122159461
# 478                0  109773545
# 495                0  300114312
# 522                0   59423648
# 552                0  426171806
# 555                0  148397415
# 618                0  184920315
# 635                0  125478348
# 647                0   38000000
# 766                0   -3244258
# 785                0  294311859
# 834                0  305000000
# 901                0  299365567
# 995                0  371925971
# 997                0  283788635
# 1135               0  131292009
# 1207               0   27673162
# 1239               0  782410554
# 1252               0   19450919
# 1284               0  205928762
# 1426               0   13461007

# %%
## How do we find risky movie?
## Risky movie --> low earning

# %%
def func(x):
    x['risky'] = x['budget'] - x['revenue'].mean() >=0
    return x

# %%
data_risky=data.groupby('director_name').apply(func)
data_risky
# Out:
# C:\Users\yuvraj.pandey\AppData\Local\Temp\ipykernel_13480\1694378429.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   data_risky=data.groupby('director_name').apply(func)
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 1460                            The Last Waltz           7.9          64
# 1461                                    Clerks           7.4         755
# 1462                                   Rampage           6.0         131
# 1463                                   Slacker           6.4          77
# 1464                               El Mariachi           6.6         238
#
#       year month       day      director_name gender  gender_mapping  \
# 0     2009   Dec  Thursday      James Cameron   Male               0
# 1     2007   May  Saturday     Gore Verbinski   Male               0
# 2     2015   Oct    Monday         Sam Mendes   Male               0
# 3     2012   Jul    Monday  Christopher Nolan   Male               0
# 4     2007   May   Tuesday          Sam Raimi   Male               0
# ...    ...   ...       ...                ...    ...             ...
# 1460  1978   May    Monday    Martin Scorsese   Male               0
# 1461  1994   Sep   Tuesday        Kevin Smith   Male               0
# 1462  2009   Aug    Friday           Uwe Boll   Male               0
# 1463  1990   Jul    Friday  Richard Linklater   Male               0
# 1464  1992   Sep    Friday   Robert Rodriguez    NaN               1
#
#           profit  risky
# 0     2550965087  False
# 1      661000000  False
# 2      635674609  False
# 3      834939099  False
# 4      632871626  False
# ...          ...    ...
# 1460      321952  False
# 1461     3124130  False
# 1462           0  False
# 1463           0  False
# 1464     1820920  False
#
# [1465 rows x 15 columns]

# %%
data_risky.loc[data_risky['risky']]
# Out:
#        id_x     budget  popularity     revenue  \
# 7     43608  200000000         107   586090727
# 12    43614  380000000         135  1045713802
# 15    43618  200000000          37   310669540
# 20    43624  209000000          64   303025485
# 24    43630  210000000           3   459359555
# ...     ...        ...         ...         ...
# 1347  47224    5000000           7     3263585
# 1349  47229    5000000           3     4842699
# 1351  47233    5000000           6           0
# 1356  47263   15000000          10           0
# 1383  47453    3500000           4           0
#
#                                             title  vote_average  vote_count  \
# 7                               Quantum of Solace           6.1        2965
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 15                                     Robin Hood           6.2        1398
# 20                                     Battleship           5.5        2114
# 24                          X-Men: The Last Stand           6.3        3525
# ...                                           ...           ...         ...
# 1347                          The Sweet Hereafter           6.8         103
# 1349                         90 Minutes in Heaven           5.4          40
# 1351                                Light Sleeper           5.7          15
# 1356                           Dying of the Light           4.5         118
# 1383                  In the Name of the King III           3.3          19
#
#       year month        day   director_name gender  gender_mapping     profit  \
# 7     2008   Oct   Thursday    Marc Forster   Male               0  386090727
# 12    2011   May   Saturday    Rob Marshall   Male               0  665713802
# 15    2010   May  Wednesday    Ridley Scott   Male               0  110669540
# 20    2012   Apr  Wednesday      Peter Berg   Male               0   94025485
# 24    2006   May  Wednesday    Brett Ratner   Male               0  249359555
# ...    ...   ...        ...             ...    ...             ...        ...
# 1347  1997   May  Wednesday     Atom Egoyan   Male               0   -1736415
# 1349  2015   Sep     Friday  Michael Polish   Male               0    -157301
# 1351  1992   Aug     Friday   Paul Schrader    NaN               1   -5000000
# 1356  2014   Dec   Thursday   Paul Schrader    NaN               1  -15000000
# 1383  2013   Dec     Friday        Uwe Boll   Male               0   -3500000
#
#       risky
# 7      True
# 12     True
# 15     True
# 20     True
# 24     True
# ...     ...
# 1347   True
# 1349   True
# 1351   True
# 1356   True
# 1383   True
#
# [131 rows x 15 columns]

# %% [markdown]
# * Yes, there are some 131 movies whose budget was greater than average earning of its director

# %%
temp = lambda a,b:True if a>b else False

# %%
temp(20,5)
# Out:
# True

# %%
num = lambda a,b:"Dancing" if a>b else "Cooking"
num
# Out:
# <function __main__.<lambda>(a, b)>

# %%
num(20,5)
# Out:
# 'Dancing'

# %%
a = 10
b = 20

# %%
if a>b:
    print("Dancing")
else:
    print("Cooking")
# Out:
# Cooking

# %%
## filter only the ages that are greater than 18
ages=[13,90,17,21,56,5]

# %%
q = lambda a:a>18

# %%
q(ages)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 q(ages)
#
# Cell In[99], line 1, in <lambda>(a)
# ----> 1 q = lambda a:a>18
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
filter(lambda a:a>18,ages)

# %%
list(filter(lambda a:a>18,ages))  # filter remove all false value
# Out:
# [90, 21, 56]

# %%
a = [5,4,3,6,7,8,3,4,56]

# %%
l=[]
for i in a:
    print(i**2)
    l.append(i**2)
    l
# Out:
# 25
# 16
# 9
# 36
# 49
# 64
# 9
# 16
# 3136

# %%
list(map(lambda a:a**2,a))
# Out:
# [25, 16, 9, 36, 49, 64, 9, 16, 3136]
